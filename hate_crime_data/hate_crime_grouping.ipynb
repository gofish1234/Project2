# %%
import pandas as pd

from flask import(
    Flask,
    render_template,
    jsonify)

from flask_sqlalchemy import SQLAlchemy

# %%
app = Flask(__name__)

# %%
# The database URI
app.config['SQLALCHEMY_DATABASE_URI'] = "sqlite:///db/hate_crime.sqlite"

db = SQLAlchemy(app)
# Out:
# C:\Users\jerri\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
class HateCrime(db.Model):
    __tablename__ = 'crime'
    
    id = db.Column(db.Integer, primary_key=True)
    year = db.Column(db.Integer)
    state = db.Column(db.String)
    region = db.Column(db.String)
    offender = db.Column(db.String)
    offense = db.Column(db.String)
    description = db.Column(db.String)
    
    df __repr__(self):
        return '<BigFoot %r>' % (self.name)

# %%
# Create a reference the CSV file desired
csv_path = "Resources/hate_crime.csv"

# Read the CSV into Pandas DataFrame
hate_df = pd.read_csv(csv_path)

hate_df.head()
# Out:
# C:\Users\jerri\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0         3015       1991  AR0040200          Rogers             NaN
# 1         3016       1991  AR0290100            Hope             NaN
# 2           43       1991  AR0350100      Pine Bluff             NaN
# 3           44       1991  AR0350100      Pine Bluff             NaN
# 4         3017       1991  AR0350100      Pine Bluff             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  \
# 0             City         AR   Arkansas  West South Central       South
# 1             City         AR   Arkansas  West South Central       South
# 2             City         AR   Arkansas  West South Central       South
# ...
