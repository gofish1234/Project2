# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
import numpy as np
import pandas as pd

# %%
# Create an engine for the chinook.sqlite database
engine = create_engine("sqlite:///../Resources/crime_income_pop.db", echo=False)

# %%
engine.execute('SELECT * FROM crime LIMIT 5').fetchall()
# Out:
# [('147593', '2010', 'Alaska', 'West', 'White', 'Aggravated Assault', 'Anti-Black or African American'),
#  ('147594', '2010', 'Alaska', 'West', 'Black or African American', 'Simple Assault', 'Anti-Gay (Male)'),
#  ('147595', '2010', 'Alaska', 'West', 'American Indian or Alaska Native', 'Simple Assault', 'Anti-White'),
#  ('147596', '2010', 'Alaska', 'West', 'American Indian or Alaska Native', 'Aggravated Assault', 'Anti-White'),
#  ('147597', '2010', 'Alaska', 'West', 'White', 'Intimidation', 'Anti-Islamic (Muslim)')]

# %%
df = pd.read_sql_query("SELECT * FROM crime;", engine)
df
# Out:
#       INCIDENT_ID DATA_YEAR     STATE_NAME REGION_NAME  \
# 0          147593      2010         Alaska        West
# 1          147594      2010         Alaska        West
# 2          147595      2010         Alaska        West
# 3          147596      2010         Alaska        West
# 4          147597      2010         Alaska        West
# 5          147598      2010         Alaska        West
# 6          147599      2010         Alaska        West
# 7          143577      2010        Alabama       South
# 8          143578      2010        Alabama       South
# 9          143579      2010        Alabama       South
# 10         143580      2010        Alabama       South
# 11         143581      2010        Alabama       South
# 12         143582      2010        Alabama       South
# 13         143583      2010        Alabama       South
# 14         143584      2010        Alabama       South
# 15         143585      2010        Alabama       South
# ...

# %%
Filtered_df = df.groupby(['DATA_YEAR', "REGION_NAME"]).count()
Filtered_df.head()

# %%
YearList_group = Filtered_df.groupby(["DATA_YEAR"])
YearList_group[".head()"]
